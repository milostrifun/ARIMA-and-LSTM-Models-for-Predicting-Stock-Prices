# %%
import pandas as pd
import numpy as np
# Load the dataset
file_path = 'CABK.MC.csv'
df_CABK = pd.read_csv(file_path)

# Check for missing values
df_CABK.isnull().sum()

df_CABK = df_CABK.interpolate(method='linear', limit_direction='both', axis=0)

# %%
# Convert 'Date' column to datetime if it's not already
df_CABK['Date'] = pd.to_datetime(df_CABK['Date'])

# Set the 'Date' column as the index
df_CABK.set_index('Date', inplace=True)

# %%
def calculate_rsi(data, window=14):
    """
    Calculate the Relative Strength Index (RSI) for a given data set and window period.
    Fills initial NaN values with the first valid RSI value.

    :param data: Pandas Series containing the stock prices.
    :param window: The period to calculate the RSI over. Default is 14.
    :return: Pandas Series containing the RSI.
    """
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()

    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))

    # Fill initial NaN values
    first_valid = rsi.first_valid_index()
    rsi[:first_valid] = rsi[first_valid]

    return rsi

# Apply the modified RSI calculation
df_CABK['RSI'] = calculate_rsi(df_CABK['Close'])

# Check for NaN values after handling RSI
print("NaNs in df_CABK after handling RSI:", df_CABK.isnull().any().any())
# Out:
# NaNs in df_CABK after handling RSI: False

# %%
# Calculate RSI
df_CABK['RSI'] = calculate_rsi(df_CABK['Close'])

# %%
# Handling NaN values if necessary
df_CABK['RSI'].fillna(method='bfill', inplace=True)  # Backward fill

# %%
import tensorflow as tf
import numpy as np

# Set seed for reproducibility
seed_value = 42
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %%
from sklearn.preprocessing import MinMaxScaler

# Select features (Close and RSI) and scale them
scaler = MinMaxScaler(feature_range=(0, 1))
selected_features = df_CABK[['Close', 'RSI']]  # Assuming RSI is added to df_CABK
scaled_features = scaler.fit_transform(selected_features)

# %%
# Define the size of the training dataset
train_size = int(len(scaled_features) * 0.8)

# Split the data into training and testing datasets
train_data, test_data = scaled_features[:train_size, :], scaled_features[train_size:, :]

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])  # Assuming 'Close' is the target
    return np.array(dataX), np.array(dataY)

# Create training and testing datasets
look_back = 1
trainX, trainY = create_dataset(train_data, look_back)
testX, testY = create_dataset(test_data, look_back)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import Adam
def create_model(units=40):
    model = Sequential()
    model.add(LSTM(units, input_shape=(look_back, 2)))  # 2 features: Close and RSI
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))
    return model

# %%
from sklearn.metrics import mean_squared_error

units_options = np.arange(40, 80, 10)
epochs_options = [100, 150]

best_score = float('inf')
best_params = {}
best_rmse = float('inf')
best_mape = float('inf')

for units in units_options:
    for epochs in epochs_options:
        tf.keras.backend.clear_session()
        model = create_model(units)
        model.fit(trainX, trainY, epochs=epochs, batch_size=1, verbose=0)

        predictions = model.predict(testX).flatten()
        mse = mean_squared_error(testY.flatten(), predictions)
        rmse = np.sqrt(mse)
        mape = np.mean(np.abs((testY.flatten() - predictions) / testY.flatten())) * 100

        if mse < best_score or (mse == best_score and (rmse < best_rmse or mape < best_mape)):
            best_score = mse
            best_rmse = rmse
            best_mape = mape
            best_params = {'units': units, 'epochs': epochs}

        print(f"Tested: Units={units}, Epochs={epochs}, MSE={mse}, RMSE={rmse}, MAPE={mape}%")

print("Best Model: MSE = %f, RMSE = %f, MAPE = %f using %s" % (best_score, best_rmse, best_mape, best_params))
# Out:
# 16/16 [==============================] - 1s 3ms/step
# Tested: Units=40, Epochs=100, MSE=0.00044433299404166753, RMSE=0.021079207623667155, MAPE=3.0264020229419266%
# 16/16 [==============================] - 0s 2ms/step
# Tested: Units=40, Epochs=150, MSE=0.00042872507467108374, RMSE=0.02070567735359275, MAPE=2.9132523843204083%
# 16/16 [==============================] - 0s 2ms/step
# Tested: Units=50, Epochs=100, MSE=0.0004463851702160053, RMSE=0.021127829283104436, MAPE=3.0319712468086237%
# 16/16 [==============================] - 1s 2ms/step
# Tested: Units=50, Epochs=150, MSE=0.0004310649475475275, RMSE=0.02076210363974536, MAPE=2.922182899687497%
# 16/16 [==============================] - 1s 2ms/step
# Tested: Units=60, Epochs=100, MSE=0.0004459949566420089, RMSE=0.021118592676644173, MAPE=3.0316297898203195%
# 16/16 [==============================] - 0s 2ms/step
# Tested: Units=60, Epochs=150, MSE=0.0004252365121109266, RMSE=0.020621263591519473, MAPE=2.901595761383892%
# 16/16 [==============================] - 0s 2ms/step
# Tested: Units=70, Epochs=100, MSE=0.00044719250695094185, RMSE=0.021146926654976174, MAPE=3.0375937257505714%
# 16/16 [==============================] - 0s 2ms/step
# Tested: Units=70, Epochs=150, MSE=0.00042771802660845296, RMSE=0.02068134489361011, MAPE=2.9095290532420712%
# Best Model: MSE = 0.000425, RMSE = 0.020621, MAPE = 2.901596 using {'units': 60, 'epochs': 150}

# %%
tf.keras.backend.clear_session()

best_units = best_params['units']
best_epochs = best_params['epochs']
model_best = create_model(units=best_units)

model_best.fit(trainX, trainY, epochs=best_epochs, batch_size=1, verbose=1)
# Out:
# Epoch 1/150
# 2046/2046 [==============================] - 8s 3ms/step - loss: 0.0115
# Epoch 2/150
# 2046/2046 [==============================] - 12s 6ms/step - loss: 5.1396e-04
# Epoch 3/150
# 2046/2046 [==============================] - 13s 7ms/step - loss: 4.7504e-04
# Epoch 4/150
# 2046/2046 [==============================] - 12s 6ms/step - loss: 4.8249e-04
# Epoch 5/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.8419e-04
# Epoch 6/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.5188e-04
# Epoch 7/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.5895e-04
# Epoch 8/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.5100e-04
# Epoch 9/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.6530e-04
# Epoch 10/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.4912e-04
# Epoch 11/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.5980e-04
# Epoch 12/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.4969e-04
# Epoch 13/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.6734e-04
# Epoch 14/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.4316e-04
# Epoch 15/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.5274e-04
# Epoch 16/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.4290e-04
# Epoch 17/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.3852e-04
# Epoch 18/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.5088e-04
# Epoch 19/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.4352e-04
# Epoch 20/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.3787e-04
# Epoch 21/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.4685e-04
# Epoch 22/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.4364e-04
# Epoch 23/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.5276e-04
# Epoch 24/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.5528e-04
# Epoch 25/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.4705e-04
# Epoch 26/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.4677e-04
# Epoch 27/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2522e-04
# Epoch 28/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.4861e-04
# Epoch 29/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.4330e-04
# Epoch 30/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.4248e-04
# Epoch 31/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.4029e-04
# Epoch 32/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2776e-04
# Epoch 33/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.3842e-04
# Epoch 34/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.3561e-04
# Epoch 35/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.3763e-04
# Epoch 36/150
# 2046/2046 [==============================] - 7s 4ms/step - loss: 4.4352e-04
# Epoch 37/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.3978e-04
# Epoch 38/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.3922e-04
# Epoch 39/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.2131e-04
# Epoch 40/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.4006e-04
# Epoch 41/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.2785e-04
# Epoch 42/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.2622e-04
# Epoch 43/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.3483e-04
# Epoch 44/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.3600e-04
# Epoch 45/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.3573e-04
# Epoch 46/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2517e-04
# Epoch 47/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2486e-04
# Epoch 48/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.2734e-04
# Epoch 49/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2293e-04
# Epoch 50/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.3419e-04
# Epoch 51/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.3032e-04
# Epoch 52/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.3033e-04
# Epoch 53/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1544e-04
# Epoch 54/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1904e-04
# Epoch 55/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.2321e-04
# Epoch 56/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2230e-04
# Epoch 57/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2806e-04
# Epoch 58/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1624e-04
# Epoch 59/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2641e-04
# Epoch 60/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.3352e-04
# Epoch 61/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.1527e-04
# Epoch 62/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.2119e-04
# Epoch 63/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.2609e-04
# Epoch 64/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2661e-04
# Epoch 65/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.2353e-04
# Epoch 66/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.2043e-04
# Epoch 67/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.3625e-04
# Epoch 68/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2589e-04
# Epoch 69/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1381e-04
# Epoch 70/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2048e-04
# Epoch 71/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1419e-04
# Epoch 72/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.2260e-04
# Epoch 73/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2592e-04
# Epoch 74/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1401e-04
# Epoch 75/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1483e-04
# Epoch 76/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2077e-04
# Epoch 77/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.2886e-04
# Epoch 78/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1834e-04
# Epoch 79/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.2587e-04
# Epoch 80/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2110e-04
# Epoch 81/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2504e-04
# Epoch 82/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1797e-04
# Epoch 83/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.2226e-04
# Epoch 84/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.2151e-04
# Epoch 85/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.2326e-04
# Epoch 86/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1041e-04
# Epoch 87/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2251e-04
# Epoch 88/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.2043e-04
# Epoch 89/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1919e-04
# Epoch 90/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2696e-04
# Epoch 91/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1546e-04
# Epoch 92/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.1826e-04
# Epoch 93/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1765e-04
# Epoch 94/150
# 2046/2046 [==============================] - 4s 2ms/step - loss: 4.1789e-04
# Epoch 95/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.0732e-04
# Epoch 96/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.2516e-04
# Epoch 97/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.2573e-04
# Epoch 98/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1204e-04
# Epoch 99/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1449e-04
# Epoch 100/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.0644e-04
# Epoch 101/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.1422e-04
# Epoch 102/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1370e-04
# Epoch 103/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1433e-04
# Epoch 104/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1401e-04
# Epoch 105/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1408e-04
# Epoch 106/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.1197e-04
# Epoch 107/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1681e-04
# Epoch 108/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1734e-04
# Epoch 109/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1632e-04
# Epoch 110/150
# 2046/2046 [==============================] - 4s 2ms/step - loss: 4.1342e-04
# Epoch 111/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1625e-04
# Epoch 112/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0885e-04
# Epoch 113/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1483e-04
# Epoch 114/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.1095e-04
# Epoch 115/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.1825e-04
# Epoch 116/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1482e-04
# Epoch 117/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0151e-04
# Epoch 118/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1423e-04
# Epoch 119/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.2374e-04
# Epoch 120/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1721e-04
# Epoch 121/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1370e-04
# Epoch 122/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1087e-04
# Epoch 123/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1111e-04
# Epoch 124/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.0646e-04
# Epoch 125/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.1469e-04
# Epoch 126/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1186e-04
# Epoch 127/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0454e-04
# Epoch 128/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.0816e-04
# Epoch 129/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.0862e-04
# Epoch 130/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.1952e-04
# Epoch 131/150
# 2046/2046 [==============================] - 7s 3ms/step - loss: 4.0382e-04
# Epoch 132/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0667e-04
# Epoch 133/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 3.9791e-04
# Epoch 134/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1282e-04
# Epoch 135/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0941e-04
# Epoch 136/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.0036e-04
# Epoch 137/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0731e-04
# Epoch 138/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.1308e-04
# Epoch 139/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.1138e-04
# Epoch 140/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0721e-04
# Epoch 141/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.0350e-04
# Epoch 142/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0240e-04
# Epoch 143/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.0960e-04
# Epoch 144/150
# 2046/2046 [==============================] - 5s 3ms/step - loss: 4.0847e-04
# Epoch 145/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0808e-04
# Epoch 146/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.0588e-04
# Epoch 147/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0694e-04
# Epoch 148/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 4.0511e-04
# Epoch 149/150
# 2046/2046 [==============================] - 6s 3ms/step - loss: 4.0897e-04
# Epoch 150/150
# 2046/2046 [==============================] - 5s 2ms/step - loss: 3.9642e-04

# %%
# Make predictions on the test dataset
testPredictions = model_best.predict(testX).flatten()

# Inverse transform to get the original scale of stock prices
testY_original = scaler.inverse_transform(np.column_stack([testY, np.zeros_like(testY)]))[:, 0]
testPredictions_original = scaler.inverse_transform(np.column_stack([testPredictions, np.zeros_like(testPredictions)]))[:, 0]
# Out:
# 16/16 [==============================] - 0s 2ms/step

# %%
# Calculate MSE, RMSE, and MAPE using the original scale values
mse = mean_squared_error(testY_original, testPredictions_original)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((testY_original - testPredictions_original) / testY_original)) * 100

# Output the performance metrics
print(f'Mean Squared Error (MSE) on Original Scale: {mse}')
print(f'Root Mean Squared Error (RMSE) on Original Scale: {rmse}')
print(f'Mean Absolute Percentage Error (MAPE) on Original Scale: {mape}%')
# Out:
# Mean Squared Error (MSE) on Original Scale: 0.0049119333423385
# Root Mean Squared Error (RMSE) on Original Scale: 0.07008518632591698
# Mean Absolute Percentage Error (MAPE) on Original Scale: 1.5473874142290518%

# %%
import matplotlib.pyplot as plt
test_dates = df_CABK.index[train_size + look_back + 1:len(df_CABK)]
# df_BBVA.index[train_size + look_back + 1:len(df_BBVA)]




# Plotting with the original scale
plt.figure(figsize=(12,6))
plt.plot(test_dates, testY_original, label='Actual Test Values', color='blue', linewidth=1)
plt.plot(test_dates, testPredictions_original, label='Predicted Test Values', color='red', linewidth=1)
plt.title('LSTM Two Feature Model: Actual vs. Predicted Stock Prices for CABK')
plt.xlabel('Time')
plt.ylabel('Stock Price (in EUR)')
plt.legend()
plt.xticks(rotation=45)
plt.show()
